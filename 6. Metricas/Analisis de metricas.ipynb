# %%
# Importamos la librerías necesarias

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %pylab
# %matplotlib inline

# Ponemos la semilla
np.random.seed(0)
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Algortimos individuales: LR, RF y DT

# %%
# Importamos el dataset 
individual = pd.read_csv('Individual.csv')

# %%
individual = individual.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
individual = individual.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=individual, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
individual = individual.sort_values('F1',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=individual, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Algortimos con Adaboost: LR, RF y DT

# %%
# Importamos el dataset 
Adaboost = pd.read_csv('Adaboost.csv')

# %%
Adaboost = Adaboost.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
Adaboost = Adaboost.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=Adaboost, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
Adaboost = Adaboost.sort_values('F1',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=Adaboost, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Algortimos con Pasting: LR, RF y DT

# %%
# Importamos el dataset 
Pasting = pd.read_csv('Pasting.csv')

# %%
Pasting = Pasting.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
Pasting = Pasting.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=Pasting, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
Pasting = Pasting.sort_values('F1',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=Pasting, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Algortimos con Bagging: LR, RF y DT

# %%
# Importamos el dataset 
Bagging = pd.read_csv('Bagging.csv')

# %%
Bagging = Bagging.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
Bagging = Bagging.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=Bagging, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
Bagging = Bagging.sort_values('F1',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=Bagging, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Algortimos con Voting: Hard & Soft with LR, RF y DT

# %%
# Importamos el dataset 
Voting = pd.read_csv('Voting.csv')

# %%
Voting = Voting.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
Voting = Voting.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=Voting, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
Voting = Voting.sort_values('F1',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=Voting, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Algortimo RNA

# %%
# Importamos el dataset 
RNA = pd.read_csv('RNA.csv')

# %%
RNA = RNA.drop(["Model Name.1", "Model Parameter"], axis = 1)

# %%
RNA = RNA.sort_values('AUC',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='AUC', y='Model Name', data=RNA, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
RNA = RNA.sort_values('Exhaustividad',ascending=False)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,5
sns.barplot(x='F1', y='Model Name', data=RNA, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %% [markdown]
# ### Top 10

# %%
# Importamos el dataset 
Metricas = pd.read_csv('Metricas.csv')

# %%
Metricas = Metricas.drop(["Model Name", "Model Parameter"], axis = 1)

# %%
Metricas = Metricas.sort_values('AUC',ascending=False)

# %%
Metricas = Metricas.head(5)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,7
sns.barplot(x='AUC', y='Model_Name', data=Metricas, label="AUC", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();

# %%
Metricas = Metricas.sort_values('F1',ascending=False)

# %%
Metricas = Metricas.head(5)

# %%
sns.set(style="whitegrid", context="notebook")
sns.set()
plt.rcParams['figure.figsize']=10,7
sns.barplot(x='F1', y='Model_Name', data=Metricas, label="F1", color='b')
plt.title("Mejor cuanto más cerca de 100")
plt.show();
